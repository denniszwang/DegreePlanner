# %% [markdown]
# <a href="https://colab.research.google.com/github/denniszwang/DegreePlanner/blob/main/Mentor_%26_Mentee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cdist
from scipy.stats import rankdata
from collections import Counter
from copy import copy

# %%
#Read in excel file
df = pd.read_excel('/content/drive/MyDrive/23MentorMenteeSheets.xlsx')
df.columns = ["time", "email", "name", "mentor_mentee", "project", "data", "UIUX", "PM", "entrepreneurship", "computer_graphics", "leetcode", "fun"]

# %%
#Store the Name & Email
name_email_map = pd.Series(df.email.values, index=df.name).to_dict()

# %%
#Seperate the mentor and mentee
df_mentor = df[df['mentor_mentee'] == 'Mentor']
df_mentee = df[df['mentor_mentee'] == 'Mentee']

# %%
def findPairs(df_mentor, df_mentee):
  placeholder_list = []
  count = 0
  mentor_columns = df_mentor.columns.tolist()
  for x in range(len(df_mentee) - len(df_mentor)):
    placeholder_list.append(["N/A", "N/A" ,"Placeholder " + str(count), "Mentor", 0, 0, 0, 0, 0, 0, 0, 0])
    count += 1
  df_placeholder = pd.DataFrame(placeholder_list, columns = mentor_columns)
  df_mentor = pd.concat([df_mentor, df_placeholder])

  mentor_names = df_mentor['name']
  mentor_list = mentor_names.tolist()
  np_mentor = df_mentor.drop(['time','email','name', 'mentor_mentee'], axis = 1).to_numpy()

  mentee_names = df_mentee['name']
  mentee_list = mentee_names.tolist()
  np_mentee = df_mentee.drop(['time','email','name', 'mentor_mentee'], axis = 1).to_numpy()

  #Calculate the preference matrix
  preference_matrix= cdist(np_mentee,np_mentor, 'euclidean')

  #Find the resulting matrix
  final_preference = np.zeros([len(preference_matrix),len(preference_matrix[0])])

  for x in range(len(preference_matrix)):
    final_preference[x] = rankdata(preference_matrix[x], 'ordinal')


  mentee_df = pd.DataFrame(final_preference, index = mentee_list, columns = mentor_list)
  mentor_df = mentee_df

  #Gale Shapely matching ALGORITHM
  # dict to control which women each man can make proposals
  mentor_available = {mentee:mentor_list for mentee in mentee_list}
  # waiting list of men that were able to create pair on each iteration
  waiting_list = []
  # dict to store created pairs
  proposals = {}
  # variable to count number of iterations
  count = 0

  # while not all men have pairs
  while len(waiting_list)<len(mentee_list):
      # man makes proposals
      for mentee in mentee_list:
          if mentee not in waiting_list:
              # each man make proposal to the top women from it's list
              mentor = mentor_available[mentee]
              best_choice = mentee_df.loc[mentee][mentee_df.loc[mentee].index.isin(mentor)].idxmin()
              proposals[(mentee, best_choice)]=(mentee_df.loc[mentee][best_choice],
                                                  mentor_df.loc[mentee][best_choice])
      # if women have more than one proposals
      # she will choose the best option
      overlays = Counter([key[1] for key in proposals.keys()])
      # cycle to choose the best options
      for mentor in overlays.keys():
          if overlays[mentor]>1:
              # pairs to drop from proposals
              pairs_to_drop = sorted({pair: proposals[pair] for pair in proposals.keys()
                      if mentor in pair}.items(),
                    key=lambda x: x[1][1]
                    )[1:]
              # if man was rejected by woman
              # there is no pint for him to make proposal
              # second time to the same woman
              for p_to_drop in pairs_to_drop:
                  del proposals[p_to_drop[0]]
                  _mentor = copy(mentor_available[p_to_drop[0][0]])
                  _mentor.remove(p_to_drop[0][1])
                  mentor_available[p_to_drop[0][0]] = _mentor
      # man who successfully created pairs must be added to the waiting list
      waiting_list = [mentee[0] for mentee in proposals.keys()]
      # update counter
      count+=1

  return proposals

# %%
def findPairsMentees(df_mentor, df_mentee):
  placeholder_list = []
  count = 0
  mentee_columns = df_mentee.columns.tolist()
  for x in range(len(df_mentor) - len(df_mentee)):
    placeholder_list.append(["N/A", "N/A" ,"Placeholder " + str(count), "Mentee", 0, 0, 0, 0, 0, 0, 0, 0])
    count += 1
  df_placeholder = pd.DataFrame(placeholder_list, columns = mentee_columns)
  df_mentee = pd.concat([df_mentee, df_placeholder])

  mentor_names = df_mentor['name']
  mentor_list = mentor_names.tolist()
  np_mentor = df_mentor.drop(['time','email','name', 'mentor_mentee'], axis = 1).to_numpy()

  mentee_names = df_mentee['name']
  mentee_list = mentee_names.tolist()
  np_mentee = df_mentee.drop(['time','email','name', 'mentor_mentee'], axis = 1).to_numpy()
  #Calculate the preference matrix
  preference_matrix= cdist(np_mentee , np_mentor, 'euclidean')

  #Find the resulting matrix
  final_preference = np.zeros([len(preference_matrix),len(preference_matrix[0])])

  for x in range(len(preference_matrix)):
    final_preference[x] = rankdata(preference_matrix[x], 'ordinal')


  mentee_df = pd.DataFrame(final_preference, index = mentee_list, columns = mentor_list)
  mentor_df = mentee_df
  #Gale Shapely matching ALGORITHM
  # dict to control which women each man can make proposals
  mentor_available = {mentee:mentor_list for mentee in mentee_list}
  # waiting list of men that were able to create pair on each iteration
  waiting_list = []
  # dict to store created pairs
  proposals = {}
  # variable to count number of iterations
  count = 0

  # while not all men have pairs
  while len(waiting_list)<len(mentee_list):
      # man makes proposals
      for mentee in mentee_list:
          if mentee not in waiting_list:
              # each man make proposal to the top women from it's list
              mentor = mentor_available[mentee]
              best_choice = mentee_df.loc[mentee][mentee_df.loc[mentee].index.isin(mentor)].idxmin()
              proposals[(mentee, best_choice)]=(mentee_df.loc[mentee][best_choice],
                                                  mentor_df.loc[mentee][best_choice])
      # if women have more than one proposals
      # she will choose the best option
      overlays = Counter([key[1] for key in proposals.keys()])
      # cycle to choose the best options
      for mentor in overlays.keys():
          if overlays[mentor]>1:
              # pairs to drop from proposals
              pairs_to_drop = sorted({pair: proposals[pair] for pair in proposals.keys()
                      if mentor in pair}.items(),
                    key=lambda x: x[1][1]
                    )[1:]
              # if man was rejected by woman
              # there is no pint for him to make proposal
              # second time to the same woman
              for p_to_drop in pairs_to_drop:
                  del proposals[p_to_drop[0]]
                  _mentor = copy(mentor_available[p_to_drop[0][0]])
                  _mentor.remove(p_to_drop[0][1])
                  mentor_available[p_to_drop[0][0]] = _mentor
      # man who successfully created pairs must be added to the waiting list
      waiting_list = [mentee[0] for mentee in proposals.keys()]
      # update counter
      count+=1

  return proposals

# %%
#df_mentor = df_mentor.sample(frac=1, random_state = 42)
#df_mentee = df_mentee.sample(frac=1, random_state = 42)

# %%
result = {}
count = 0
while len(df_mentee) >= len(df_mentor):
    iteration_result = findPairs(df_mentor, df_mentee)
    mentee_list = []
    for keys in iteration_result:
        mentor_name = keys[1]
        mentee_name = keys[0]
        # Lookup emails
        mentor_email = name_email_map.get(mentor_name, "Email not found")
        mentee_email = name_email_map.get(mentee_name, "Email not found")

        mentor_info = f"{mentor_name} ({mentor_email})"
        mentee_info = f"{mentee_name} ({mentee_email})"

        if 'Placeholder' not in mentor_name:
            if mentor_info in result:
                result[mentor_info].append(mentee_info)
            else:
                result[mentor_info] = [mentee_info]
        else:
            mentee_list.append(mentee_name)  # Keep using name for filtering in df_mentee
    df_mentee = df_mentee[df_mentee['name'].isin(mentee_list)]
    count += 1

if len(df_mentee) > 0:
    mentee_result = findPairsMentees(df_mentor, df_mentee)

    for keys in mentee_result:
        mentor_name = keys[1]
        mentee_name = keys[0]
        # Lookup emails
        mentor_email = name_email_map.get(mentor_name, "Email not found")
        mentee_email = name_email_map.get(mentee_name, "Email not found")

        mentor_info = f"{mentor_name} ({mentor_email})"
        mentee_info = f"{mentee_name} ({mentee_email})"

        if 'Placeholder' not in mentor_name:
            if mentor_info in result:
                result[mentor_info].append(mentee_info)
            else:
                result[mentor_info] = [mentee_info]

# %%
result
# Out:
# {'Yuxiang Wang (ywang20@seas.upenn.edu)': ['Marisol Sanchez (smarisol@seas.upenn.edu)',
#   'Lisa Ling (lisaling.yx@gmail.com)',
#   'Hao Tan (tanhao@seas.upenn.edu)'],
#  'Klaus Chen (zheyic@seas.upenn.edu)': ['Ganlin Ouyang (ouyangga@seas.upenn.edu)',
#   'Zhe Wang (denwang@seas.upenn.edu)',
#   'Ziqi (Grace) Hua (ziqihua@seas.upenn.edu)'],
#  'Yifei Duan (dyifei@seas.upenn.edu)': ['Tengxiao Song (tengxiao@seas.upenn.edu)',
#   'Steve Wang (qian.wang.wg24@wharton.upenn.edu)',
#   'Qingxuan Wu (qxwu@seas.upenn.edu)'],
#  'Zechuan Yang (Zacyang@upenn.edu)': ['YIHUAI ZHANG (yihuaiz@seas.upenn.edu)',
#   'Yixuan Gao (yixuang@seas.upenn.edu)',
#   'Muhan Liu (muhanliu@seas.upenn.edu)'],
#  'Sean Chuang (seanc7@seas.upenn.edu)': ['Nollie(HuiYu) Chen (nollie@seas.upenn.edu)',
#   'Sharon Yu (sharonyu@seas.upenn.edu)',
#   'Zhaoxuan Huang (hzx714@seas.upenn.edu)'],
#  'Mia (diyang1@seas.upenn.edu)': ['Sophie Wang (wso@wharton.upenn.edu)',
#   'Alice Hobbs (ahobbs1@seas.upenn.edu)',
#   'Paul (kathmann@seas.upenn.edu)'],
#  'Elena Peng (pexy@seas.upenn.edu)': ['Joel Mandell (jmandel2@seas.upenn.edu)',
#   'Chengpu Liao (chengpu@seas.upenn.edu)',
#   'Jason Su (jasonsu.161@gmail.com)'],
#  'Yan Zhang (yan5@seas.upenn.edu)': ['Nikita Singh (niks19@seas.upenn.edu)',
#   'Jihan Chen (jihanc@seas.upenn.edu)',
#   'Huong Huynh (helenahh@seas.upenn.edu)'],
#  'Siddharth (Sid) Sannapareddy (sidsan@seas.upenn.edu)': ['Chloe Benoit (cbenoit@seas.upenn.edu)',
#   'Andrew Zolensky (zolensky@seas.upenn.edu)',
#   'Jessie Levin (jessiel@seas.upenn.edu)'],
#  'Antina Yeh (antina@sesa.upenn.edu)': ['Joshua Benadiva (benadiva@wharton.upenn.edu)',
#   'chenrui hu (chenruih@seas.upenn.edu)',
#   'McKenna Reale (mreale@seas.upenn.edu)'],
#  'Peici Qiu  (peiciqiu@seas.upenn.edu)': ['Zairui Yang (zairuiy@seas.upenn.edu)',
#   'Gabrielle Lyu (gablyu@seas.upenn.edu)',
#   'Caroline Park (cspark@seas.upenn.edu)'],
#  'Zhechen Zhu (zhechenz@seas.upenn.edu)': ['Shutong Jiang (ryjiang@seas.upenn.edu)',
#   'Nico Tripeny (ntripeny@seas.upenn.edu)',
#   'Xiaoying Zhang (zbzxy@upenn.edu)'],
#  'Norris Chen (norrisch@seas.upenn.edu)': ['Katelyn Vo (katevo@seas.upenn.edu)',
#   'Amaal Abdi (aabdi@seas.upenn.edu)',
#   'Frida Spatscheck (fridas@seas.upenn.edu)'],
#  'Richard Huang (richuang@seas.upenn.edu)': ['Leyi Jiang (lorinej@seas.upenn.edu)',
#   'James Chin (jamesewc@seas.upenn.edu)',
#   'Rachel Feng (rcfeng@seas.upenn.edu)'],
#  'Ye Tao (adatao@seas.upenn.edu)': ['Ana Bernal  (anbernal@seas.upenn.edu)',
#   'Ally Kim (allykiim@seas.upenn.edu)',
#   'Ji Hyun Kim (jhkim10@seas.upenn.edu)'],
#  'Armaan Rathi (armaanr@seas.upenn.edu)': ['Cynthia Zhou (cynzhou@wharton.upenn.edu)',
#   'JIANGMAN ZHAO (lobizhao@seas.uepnn.edu)',
#   'Zhitong Chen (ztchen@seas.upenn.edu)'],
#  'You Shen (youshen@seas.upenn.edu)': ['Ziyi Li (ziyil@seas.upenn.edu)',
#   'haoyu zhao (haoyzhao@seas.upenn.edu)',
#   'Nimisha Malik (nimmalik@seas.upenn.edu)'],
#  'Akanksha Ashok (aashok@seas.upenn.edu)': ['Xinye Zhang (xinyezh@seas.upenn.edu)',
#   'Yuchen Liu (liuyuche@seas.upenn.edu)',
#   'Rae Zhu (ztr@seas.upenn.edu)'],
#  'Tianhao Xu (xu000546@seas.upenn.edu)': ['Perrie Quek (queky@seas.upenn.edu)',
#   'Ijeoma Okoye (ijoloye@seas.upenn.edu)',
#   'Xinran Zhu (xinranzh@seas.upenn.edu)'],
#  'Wei-Hou Huang (huangwh@seas.upenn.edu)': ['Justin Lu (jzl@seas.upenn.edu)',
#   'Abigail Zhong  (qingmiao@seas.upenn.edu)',
#   'Mikhael Zacharias Thomas (mikth@seas.upenn.edu)'],
#  'Alette Ng (aletteng@seas.upenn.edu)': ['Robert Thomas Bunch (thomasb1205@gmail.com)',
#   'Arpan Bagui (abagui@wharton.upenn.edu)',
#   'Thrisna Singh (thrisna@seas.upenn.edu)'],
#  'Joseph Himes (himesj@seas.upenn.edu)': ['Muyu He (muyuhe@seas.upenn.edu)',
#   'Rubo Xing (rubo@seas.upenn.edu)',
#   'Chimezie Maduno (cjmaduno@seas.upenn.edu)'],
#  'Priya DCosta  (pdcosta@seas.upenn.edu)': ['Haoyi Cheng (haoyic@seas.upenn.edu)',
#   'Andres Mondragon (amt00@upenn.edu)',
#   'Placeholder 0 (Email not found)'],
#  'Michael Mason (micmas@seas.upenn.edu)': ['Liya Zhang (liyaz@seas.upenn.edu)',
#   'Austin Lin (austinkt@seas.upenn.edu)',
#   'Yucheng Zhu (yuchengz@seas.upenn.edu)']}

# %%
final = pd.DataFrame(result.items(), columns=['Mentors', 'Mentees'])
final = final.explode('Mentees').reset_index(drop=True)

last_mentor = None
for index, row in final.iterrows():
    current_mentor = row['Mentors']
    if current_mentor == last_mentor:
        final.at[index, 'Mentors'] = ''  # Clear the mentor name
    else:
        last_mentor = current_mentor

final[['Mentor Name', 'Mentor Email']] = final['Mentors'].str.extract(r'(.*)\s\((.*)\)', expand=True)
final[['Mentee Name', 'Mentee Email']] = final['Mentees'].str.extract(r'(.*)\s\((.*)\)', expand=True)
final = final.drop(['Mentors', 'Mentees'], axis=1)
final.fillna('', inplace=True)
final
# Out:
#       Mentor Name            Mentor Email       Mentee Name  \
# 0    Yuxiang Wang  ywang20@seas.upenn.edu   Marisol Sanchez
# 1                                                 Lisa Ling
# 2                                                   Hao Tan
# 3      Klaus Chen   zheyic@seas.upenn.edu     Ganlin Ouyang
# 4                                                  Zhe Wang
# ..            ...                     ...               ...
# 67                                         Andres Mondragon
# 68                                            Placeholder 0
# 69  Michael Mason   micmas@seas.upenn.edu        Liya Zhang
# 70                                               Austin Lin
# 71                                              Yucheng Zhu
#
#                Mentee Email
# 0   smarisol@seas.upenn.edu
# 1     lisaling.yx@gmail.com
# 2     tanhao@seas.upenn.edu
# 3   ouyangga@seas.upenn.edu
# 4    denwang@seas.upenn.edu
# ..                      ...
# 67          amt00@upenn.edu
# 68          Email not found
# 69     liyaz@seas.upenn.edu
# 70  austinkt@seas.upenn.edu
# 71  yuchengz@seas.upenn.edu
#
# [72 rows x 4 columns]

# %%
final_exploded.to_excel("/content/drive/MyDrive/MentorMenteeResult.xlsx")
